# %%
n = int(input())
sum = 0
while n > 0:
  digit = n % 10
  sum = sum + digit
  n = n // 10
print(sum)
# Out:
# 123
# 6

# %%
n = int(input())
a = 1
while n > 0:
   a = a * (n % 10)
   n = n // 10
print(a)
# Out:
# 195
# 45

# %%
n = int(input())
for element in range(7, n, 7):
  print(element)
# Out:
# 256
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98
# 105
# 112
# 119
# 126
# 133
# 140
# 147
# 154
# 161
# 168
# 175
# 182
# 189
# 196
# 203
# 210
# 217
# 224
# 231
# 238
# 245
# 252
